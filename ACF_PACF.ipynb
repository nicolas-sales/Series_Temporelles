# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
import statsmodels.api as sm

# %%
from statsmodels.tsa.stattools import acovf, acf, pacf, pacf_yw, pacf_ols

# %% [markdown]
# # df1 : no stationnary series / df2 : stationnary series

# %%
df1 = pd.read_csv(r'C:\Users\nico_\Desktop\Time series\UDEMY_TSA_FINAL\UDEMY_TSA_FINAL\Data\airline_passengers.csv', index_col='Month', parse_dates=True)

# %%
df1.index.freq = 'MS' # monthly data

# %%
df2 = pd.read_csv(r'C:\Users\nico_\Desktop\Time series\UDEMY_TSA_FINAL\UDEMY_TSA_FINAL\Data\DailyTotalFemaleBirths.csv', index_col='Date', parse_dates=True)

# %%
df2.index.freq='D' # daily data

# %%
df1.head()
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121

# %%
df1.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
df2.head()
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44

# %%
df2.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Lag plot

# %%
from pandas.plotting import lag_plot

# %%
lag_plot(df1['Thousands of Passengers'])
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 1)'>

# %% [markdown]
# ### Very strong autocorrelation

# %%
lag_plot(df2['Births'])
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 1)'>

# %% [markdown]
# ### Not strong autocorrelation

# %% [markdown]
# ## acf plot

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(df1, lags=40);

# %%
plot_acf(df2, lags=40);

# %% [markdown]
# ## pacf plot

# %%
plot_pacf(df1, lags=40);

# %%
plot_pacf(df2, lags=40);
