# %%
import pandas as pd
from prophet import Prophet
import matplotlib.pyplot as plt
# %matplotlib inline
from prophet.plot import add_changepoints_to_plot

# %%
df = pd.read_csv(r'C:\Users\nico_\Desktop\Time series\UDEMY_TSA_FINAL\UDEMY_TSA_FINAL\Data\airline_passengers.csv')

# %%
df.head()
# Out:
#      Month  Thousands of Passengers
# 0  1949-01                      112
# 1  1949-02                      118
# 2  1949-03                      132
# 3  1949-04                      129
# 4  1949-05                      121

# %%
df.tail()
# Out:
#        Month  Thousands of Passengers
# 139  1960-08                      606
# 140  1960-09                      508
# 141  1960-10                      461
# 142  1960-11                      390
# 143  1960-12                      432

# %%
len(df)
# Out:
# 144

# %%
df.columns = ['ds','y']

# %%
df['ds']  =pd.to_datetime(df['ds'])

# %%
m = Prophet()
m.fit(df)
future = m.make_future_dataframe(periods=50, freq='MS')
forecast = m.predict(future)
# Out:
# 12:09:26 - cmdstanpy - INFO - Chain [1] start processing
# 12:09:26 - cmdstanpy - INFO - Chain [1] done processing

# %%
fig = m.plot(forecast)

# %%
fig = m.plot_components(forecast)

# %%
fig = m.plot(forecast)
a = add_changepoints_to_plot(fig.gca(),m,forecast)

# %% [markdown]
# ## Multiplicative model

# %%
m = Prophet(seasonality_mode='multiplicative')
m.fit(df)
future = m.make_future_dataframe(periods=50, freq='MS')
forecast = m.predict(future)
# Out:
# 12:20:48 - cmdstanpy - INFO - Chain [1] start processing
# 12:20:48 - cmdstanpy - INFO - Chain [1] done processing

# %%
fig = m.plot(forecast)

# %%
fig = m.plot_components(forecast)
